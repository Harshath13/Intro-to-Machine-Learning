# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshath13/Machine-Learning-Assignments/blob/main/Digit_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv 
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test,y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis =1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape =(28,28)))
model.add(tf.keras.layers.Dense(units = 128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(units =10, activation = tf.nn.softmax))

model.compile(optimizer = 'adam' , loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

model.fit(x_train,y_train,epochs = 30)

accuracy , loss = model.evaluate(x_test,y_test)
print(accuracy)
print(loss)

model.save('digits.model')
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3201 - accuracy: 0.9106
# Epoch 2/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1461 - accuracy: 0.9568
# Epoch 3/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1006 - accuracy: 0.9699
# Epoch 4/30
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0746 - accuracy: 0.9781
# Epoch 5/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0597 - accuracy: 0.9824
# Epoch 6/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0465 - accuracy: 0.9864
# Epoch 7/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0383 - accuracy: 0.9883
# Epoch 8/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0303 - accuracy: 0.9912
# Epoch 9/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0246 - accuracy: 0.9931
# Epoch 10/30
# ...

# %%
import glob
#for x in range (1,6):
img = cv.imread('/content/digits.model/.png')[ :28,:28,0 ]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print(np.argmax(prediction))
plt.imshow(img[0], cmap = plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 4

# %%
from os import listdir
from os.path import isfile, join
import numpy
import cv2

mypath='/content/digits.model'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = numpy.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
  images[n] = cv2.imread( join(mypath,onlyfiles[n]) )
  plt.imshow(images[0])
  plt.show()

# %%
import glob
import cv2 as cv

path = glob.glob("/content/digits.model/*.png")
cv_img = []
for img in path:
    n = cv.imread(img)
    cv_img.append(n)
    plt.imshow(cv_img[0])
    plt.show()

# %%
 #print(cv.getBuildInformation())
